# %%
ids = ["A001", "A002", "A003"]
names = ["Ana", "Luis", "Maria"]
scores = [90, 85, 92]

# %%
students = {}

for id, name, score in zip(ids, names, scores):
    students[id] = {'name': name, 'score': score}
    
print(students)
