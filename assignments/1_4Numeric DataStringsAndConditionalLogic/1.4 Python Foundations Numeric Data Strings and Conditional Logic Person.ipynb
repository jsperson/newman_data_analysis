# %% [markdown]
# # Section 5: Numeric Data

# %% [markdown]
# ## Numeric Data Types
# 1. Integers(int) - whole number without decimal points
# 2. Floats(float) - real numbers with decimal points
# 3. Complex(complex) - numberes with both real and impaginary portions

# %% [markdown]
# ## Numeric Type Conversions

# %%
# Conversion examples
number = 1.9999
print(type(number))

# Converting float to integer returns only the whole number component
fixed_number = int(number)
print(fixed_number, type(fixed_number))

# Converting integer to float adds zero as the floating component
number = 1
float_number = float(number)
print(float_number, type(float_number))

# Convert string to number
text = '1.5'
type(text)
float_number = float(text)
print(float_number, type(float_number))

# Converting a string with letter characters will return an error
number = 'abc123'
# Commented out to allow the notebook to run
# fixed_number = int(number)
# Out:
# <class 'float'>
# 1 <class 'int'>
# 1.0 <class 'float'>
# 1.5 <class 'float'>

# %% [markdown]
# ## Arithmetic Operators
# * Addition
# * Subtraction
# * Multiplication
# * Division
# * Floor Divition (//) - returns the largest integer that is less than or equal to the result of the division
# * Modulo
# * Exponentiation

# %% [markdown]
# ## DEMO: Numeric Functions

# %%
my_string = '3579'
my_float = 3.579
my_int = 3

# %%
int(my_string)
# Out:
# 3579

# %%
int(my_float)
# Out:
# 3

# %%
float(my_string)
# Out:
# 3579.0

# %%
float(my_int)
# Out:
# 3.0

# %%
my_int + my_float
# Out:
# 6.579000000000001

# %%
my_int - my_float
# Out:
# -0.5790000000000002

# %%
my_float - my_int
# Out:
# 0.5790000000000002

# %%
my_int * my_float
# Out:
# 10.737

# %%
my_int / my_float
# Out:
# 0.8382229673093042

# %%
my_int // my_float
# Out:
# 0.0

# %%
my_int % my_float
# Out:
# 3.0

# %%
my_int**my_float
# Out:
# 51.00549546541933

# %%
10 * 6 - 3**2
# Out:
# 51

# %%
10 * (6 - 3)**2
# Out:
# 90

# %% [markdown]
# ## Assignment: Arithmetic Operators

# %% [markdown]
# ### 1. Calculate the gross profit on our snowboard
# Formula: Price minus cost

# %%
snowboard_price = 499.99
snowboard_cost = 199.99

# %% [markdown]
# ### 2. Calculate the gross margin on our snowboard
#
# Formula: Gross profit divided by price

# %%
gross_margin = (snowboard_price - snowboard_cost)/snowboard_price
print(gross_margin)
# Out:
# 0.6000120002400048

# %% [markdown]
# ### 3. Calculate the price needed to obtain a gross margin of 70%
#
# Formula: cost divided by (1 minus the desired margin).

# %%
price_needed_for70 = snowboard_cost / (1 - 0.70)
print(price_needed_for70)
# Out:
# 666.6333333333332

# %% [markdown]
# ### 4. Calculate the sales tax on a sale of our snowboard
#
# Tax rate: 8%
#
# Formula: Price times tax rate

# %%
sales_tax = snowboard_price * 0.08
print(int(sales_tax))
# Out:
# 39

# %% [markdown]
# ### 5. Return on Profits
#
# Calculate the amount of money we'd have if we invested the profit from selling 5 snowboards for one year.
#
# Assume an interest rate of 5%.
#
# The formula is the amount_invested plus (amount_invested times interest_rate)

# %%
snowboard_profit = snowboard_price - snowboard_cost
investment_amount = 5 * snowboard_profit
amount_after_1yr = investment_amount + (investment_amount * 0.05)
print(amount_after_1yr)
# Out:
# 1575.0

# %% [markdown]
# ## Numeric Functions
# ### Single Number
# * round(number, # of digits)
# * abs(number)
# ### Multiple Numbers
# * sum(iterable)
# * min(iterable)
# * max(iterable)

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
round(3.14159)
# Out:
# 3

# %%
round(3.51)
# Out:
# 4

# %%
abs(-3)
# Out:
# 3

# %%
list_vals = [1,2,3,4,5]
print(sum(list_vals))
print(min(list_vals))
print(max(list_vals))
# Out:
# 15
# 1
# 5

# %% [markdown]
# ## Demo: Numeric Functions

# %%
number = 3.579

# %%
round(number)
# Out:
# 4

# %%
round(number, 2)
# Out:
# 3.58

# %%
round(number, 1)
# Out:
# 3.6

# %%
abs(number)
# Out:
# 3.579

# %%
abs(-number)
# Out:
# 3.579

# %%
numbers = (5, 10, 15)

# %%
max(numbers)
# Out:
# 15

# %%
golf_scores = [-3, 0, 2, 30]

# %%
min(golf_scores)
# Out:
# -3

# %%
max(golf_scores)
# Out:
# 30

# %%
sum(golf_scores)
# Out:
# 29

# %%
sum(golf_scores, 3)
# Out:
# 32

# %% [markdown]
# ## Assignment: Numeric Functions

# %% [markdown]
# ### What are the highest and lowest priced items we sell?
#
# Based on the list of prices below. Use Python to determine this.

# %%
price_list = [129.99, 99.99, 119.19, 99.99, 89.99, 79.99, 49.99]

# %% [markdown]
# How much would it cost for a customer to purchase two of every item in the price list?

# %%
highest_price = max(price_list)
print(highest_price)
# Out:
# 129.99

# %%
lowest_price = min(price_list)
print(lowest_price)
# Out:
# 49.99

# %%
two_all_items = 2 * sum(price_list)
print(round(two_all_items))
# Out:
# 1338

# %% [markdown]
# # Section 6: Strings

# %%
new_string = 'This is a "string".'
print(new_string)
# Out:
# This is a "string".

# %% [markdown]
# Can use either single or double quotes for strings.

# %%
newer_string = '''This allows
multiple lines!
'''
print(newer_string)
# Out:
# This allows
# multiple lines!

# %% [markdown]
# ## String Arithmetic

# %%
'snow' + 'board'
# Out:
# 'snowboard'

# %%
subject = 'My'
noun = 'Maven snowboard'
verb = 'cost'
price = 22.55
subject + ' ' + noun + ' ' + verb + ' ' + ' $' + str(price) + '!'
# Out:
# 'My Maven snowboard cost  $22.55!'

# %%
'repeat this ' * 3
# Out:
# 'repeat this repeat this repeat this '

# %% [markdown]
# ## Demo: String Creation & Arithmetic

# %%
movie = 'Mega Blockbuster'
print(movie)
# Out:
# Mega Blockbuster

# %%
# Use double quotes to have apostorphe in string
# Could use \ to escape but not pythonic
movie = "It's a Mega Blockbuster"
print(movie)
# Out:
# It's a Mega Blockbuster

# %%
# Works the other way too
movie = '"Mega" Blockbuster'
print(movie)
# Out:
# "Mega" Blockbuster

# %%
movie = '''It's a "Mega" Blockbuster was a very good
movie and I want to 
see it again so badly'''
print(movie)
# Out:
# It's a "Mega" Blockbuster was a very good
# movie and I want to
# see it again so badly

# %%
movie = 'Mega Blockbuster'
review = 'Was very good'
print(movie + ' ' + review.lower())
# Out:
# Mega Blockbuster was very good

# %%
(movie + ' ') * 4
# Out:
# 'Mega Blockbuster Mega Blockbuster Mega Blockbuster Mega Blockbuster '

# %% [markdown]
# ## String Indexing
# Strings and sequence data types are zero indexed

# %%
message = 'I hope it snows tonight!'

# %%
message[0]
# Out:
# 'I'

# %%
message[2]
# Out:
# 'h'

# %%
# Negative indexing
message[-1]
# Out:
# '!'

# %% [markdown]
# ## Demo: String Indexing

# %%
movie = "It's a Mega Blockbuster"
movie[0]
# Out:
# 'I'

# %%
movie[3]
# Out:
# 's'

# %%
movie[-1]
# Out:
# 'r'

# %%
movie[-2]
# Out:
# 'e'

# %% [markdown]
# ## Assignment: String Indexing

# %% [markdown]
# ### Password Retrieval
#
# * Spell the word 'Maven' by grabbing one letter from each text message

# %%
text1 = '          Your friend Mark'
text2 = 'was'
text3 = 'having'
text4 = 'a great day'
text5 = 'on the mountain'

# %%
# Your code goes here - combine the letters in to a word and assign to the variable 'maven'
maven = text5[-8] + text3[1] + text3[2] + text1[-8] + text5[1]

print('The secret password is ' + maven)
# Out:
# The secret password is maven

# %% [markdown]
# ## String Slicing
# ```
# [start:stop:step size]
# ```

# %%
message = "I hope it snows tonight!"
message[0:6:1]
# Out:
# 'I hope'

# %%
message[2:6]
# Out:
# 'hope'

# %%
message[:6]
# Out:
# 'I hope'

# %%
message[6:]
# Out:
# ' it snows tonight!'

# %%
message[0:6:2]
# Out:
# 'Ihp'

# %%
message[::-1]
# Out:
# '!thginot swons ti epoh I'

# %%
message[-9:-1:1]
# Out:
# ' tonight'

# %% [markdown]
# ## Demo: String Slicing

# %%
movie = "It's a Mega Blockbuster"

# %%
movie[0:4]
# Out:
# "It's"

# %%
movie[4:]
# Out:
# ' a Mega Blockbuster'

# %%
movie[5:]
# Out:
# 'a Mega Blockbuster'

# %%
movie[::2]
# Out:
# "I'  eaBokutr"

# %%
movie[::3]
# Out:
# 'Is gBcue'

# %%
movie[::-1]
# Out:
# "retsubkcolB ageM a s'tI"

# %%
movie[-6::]
# Out:
# 'buster'

# %% [markdown]
# ## Assignment: String Slicing

# %% [markdown]
# ### Marketing Copy
#
# Our testimonial is in the first cell below, assigned to testimonial.
#
# Run the cell to create the string.

# %%
testimonial = '''I love skiing. It's my favorite hobby.
Some people say, "It's not a hobby, it's life."
'''

# %% [markdown]
# ### First Draft
#
# Please create the message 'I love skiing. It's my life.' by slicing  testimonial.
#
# Assign this message to a variable called short_testimonial, and print it.

# %%
short_testimonial = testimonial[0:14] + testimonial[14:23] + testimonial[-7:-2]
print(short_testimonial)
# Out:
# I love skiing. It's my life.

# %% [markdown]
# ### Second Draft
#
# We might need to shorten the message (we pay by the word).
#
# Slice short_testimonial down to 'I love my life!'.
#
# You may need to add an exclamation point. Assign this message to happy_customer, and print it.

# %%
happy_customer = testimonial[0:7] + testimonial[20:23] + testimonial[-7:-3] + "!"
print(happy_customer)
# Out:
# I love my life!

# %% [markdown]
# ## Length Function

# %%
len('snowboard')
# Out:
# 9

# %%
len([1,2,3])
# Out:
# 3

# %% [markdown]
# ## Assignment: String Length

# %% [markdown]
# ### Cryptography
#
# Hi there!
#
# There are five text message below. I've also convieniently pasted the alphabet for you, which we'll need to crack the code.
#
# The length of each message represents the letter in the alphabet for each character in the password.

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'
message1 = 'Hello World!'
message2 = ''
message3 = 'It snowed a lot today'
message4 = 'eeee'
message5 = 'I love snow!!'

# %% [markdown]
# ### Crack the Code
#
# In the cell below, combine the characters retrieved using the length function into a single string, and assign that to password. Then print the password.

# %%
password = (alphabet[len(message1)]
            + alphabet[len(message2)] 
            + alphabet[len(message3)] 
            + alphabet[len(message4)] 
            + alphabet[len(message5)]
           )
print(password)
# Out:
# maven

# %% [markdown]
# ## String Methods
# * find
# * upper
# * lower
# * strip
# * replace
# * split
# * join

# %%
message = "I hope it snows tonight!"
message.replace('snow', 'rain')
# Out:
# 'I hope it rains tonight!'

# %%
message = ".test.   "
print(message.strip(),'*') # Strip the spaces
print(message.lstrip('.'),'*') # Strip the left .
print(message.strip().strip('.'),'*') # Strip the spaces and both .
# Out:
# .test. *
# test.    *
# test *

# %%
message = "I hope it snows tonight!"
word_list = message.split(' ')

# %%
' '.join(word_list)
# Out:
# 'I hope it snows tonight!'

# %% [markdown]
# ## Demo: String Methods

# %%
movie = "It's a Mega Blockbuster!"

# %%
movie.upper()
# Out:
# "IT'S A MEGA BLOCKBUSTER!"

# %%
movie.lower()
# Out:
# "it's a mega blockbuster!"

# %%
movie.strip('!')
# Out:
# "It's a Mega Blockbuster"

# %%
movie.rstrip('!')
# Out:
# "It's a Mega Blockbuster"

# %%
movie.lstrip('!')
# Out:
# "It's a Mega Blockbuster!"

# %%
movie.replace('!','.')
# Out:
# "It's a Mega Blockbuster."

# %%
word_list = movie.split()
print(word_list)
# Out:
# ["It's", 'a', 'Mega', 'Blockbuster!']

# %%
movie.split("'")
# Out:
# ['It', 's a Mega Blockbuster!']

# %%
' '.join(word_list)
# Out:
# "It's a Mega Blockbuster!"

# %%
', '.join(word_list)
# Out:
# "It's, a, Mega, Blockbuster!"

# %%
movie.lower().replace("'","#")
# Out:
# 'it#s a mega blockbuster!'

# %% [markdown]
# ## Assignment: String Methods

# %% [markdown]
# ### New Marketing Copy
#
# Ok, time to draft some more copy - the CEO wasn't pleased that we didn't mention a ski shop in our last version.
#
# Below are five text messages we need to draw from.

# %%
text1 = '          Your friend Mark'
text2 = 'was'
text3 = 'having'
text4 = 'a great day'
text5 = 'on the mountain'

# %% [markdown]
# ### Combine the Texts
#
# Combine the messages into a single string, assigned to full_text.

# %%
full_text = ' '.join([text1, text2, text3, text4, text5])

full_text
# Out:
# '          Your friend Mark was having a great day on the mountain'

# %% [markdown]
# ### Clean it up
#
# Remove the leading spaces and let's make it all lower case for now.

# %%
fixed_text = full_text.lstrip().lower()

fixed_text
# Out:
# 'your friend mark was having a great day on the mountain'

# %% [markdown]
# ### A SLIGHT Change
#
# Change the portion of the message that reads 'on the mountain' to 'at the ski shop'.

# %%
new_text = fixed_text.replace('on the mountain', 'at the ski shop')

new_text
# Out:
# 'your friend mark was having a great day at the ski shop'

# %% [markdown]
# ### Count the words
#
# Look up a string method here that can help us count the number of words in our messages. We just need to count how many spaces there are and add 1.

# %%
word_count = new_text.count(' ') + 1

word_count
# Out:
# 12

# %% [markdown]
# ## F-Strings

# %%
name = 'Chris'
role = 'employee'

print(f"{name} is our favorite {role}, or course!")
# Out:
# Chris is our favorite employee, or course!

# %% [markdown]
# ## Demo: F-Strings

# %%
movie = 'A Mega Blockbuster III'

# %%
print(f'My favorite movie is: {movie.upper() * 2}!')
# Out:
# My favorite movie is: A MEGA BLOCKBUSTER IIIA MEGA BLOCKBUSTER III!

# %% [markdown]
# ## Assignment: F-Strings

# %% [markdown]
# ### Price Display Message
#
# Using f-strings, print 'The product costs $price.' for each of the price/product combinations below.
#
# Your print statement should be identical for both.

# %%
price = 499.99
product = 'snowboard'

# your print statement here
print(f"The {product} costs ${price}.")
# Out:
# The snowboard costs $499.99.

# %%
price = 19.99
product = 'scarf'

# exact copy of print statement in first cell
print(f"The {product} costs ${price}.")
# Out:
# The scarf costs $19.99.

# %% [markdown]
# # Section 7: Conditional Logic

# %% [markdown]
# ### Boolean Data Type
# 0/1 True/False

# %% [markdown]
# ## Comparison Operators
# * == Equal
# * != Not Equal
# * < Less Than
# * \> Greater Than
# * <= Less Than or Equal
# * \>= Greater Than or Equal

# %% [markdown]
# ## Membership Tests

# %%
message = 'I hope it snows tonight!'
print('snow' in message)
# Out:
# True

# %%
print('rain' in message)
# Out:
# False

# %%
print('snow' not in message)
# Out:
# False

# %% [markdown]
# ## and And or

# %%
5 > 4 and 7 > 8
# Out:
# False

# %%
5 > 4 or 7 > 8
# Out:
# True

# %%
15 > 10 and 11 > 10 and 12 > 10
# Out:
# True

# %% [markdown]
# Note: python will short circuit evaluation of and/or chains. So order can matter for efficiency

# %% [markdown]
# ## Demo: Boolean Data Types and Operators

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
10 * True
# Out:
# 10

# %%
10 * False
# Out:
# 0

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
(not False) * 10
# Out:
# 10

# %%
'word' == 'word'
# Out:
# True

# %%
'word' == 'WORD'
# Out:
# False

# %%
'word' == 'WORD'.lower()
# Out:
# True

# %%
'word' != 'word'
# Out:
# False

# %%
len('word') > len('word')
# Out:
# False

# %%
len('word') >= len('word')
# Out:
# True

# %%
len('words') > len('word')
# Out:
# True

# %%
len('word') < len('word')
# Out:
# False

# %%
len('word') <= len('word')
# Out:
# True

# %%
'or' in 'word'
# Out:
# True

# %%
'nor' in 'word'
# Out:
# False

# %%
'nor' not in 'word'
# Out:
# True

# %%
my_list = [1, 2, 3]

# %%
2 in my_list
# Out:
# True

# %%
4 in my_list
# Out:
# False

# %%
3 in my_list and 'nor' in 'word'
# Out:
# False

# %%
3 in my_list or 'nor' in 'word'
# Out:
# True

# %%
3 in my_list or 'nor' in word # short circuited so error doesn't show up
# Out:
# True

# %%
# commented out because I want the notebook to run and this returns an error
# 3 in my_list and 'nor' in word

# %%
4 in my_list or ('nor' in 'word' and 'd' in 'word')
# Out:
# False

# %% [markdown]
# ## Assignment: Boolean Operators

# %% [markdown]
# ### Inventory Logic
#
# I need you to create some logic that returns Boolean values depending on Inventory levels and other factors.
#
# Our current inventory level is 5 units.

# %%
inventory_count = 5

# %% [markdown]
# ### Do we have any stock?
#
# Write logic that returns True if we have 0 units of inventory.

# %%
inventory_count == 0
# Out:
# False

# %% [markdown]
# ### Do we have a safe level of inventory?
#
# Write logic that returns True if we have more than five units of inventory.

# %%
inventory_count > 5
# Out:
# False

# %% [markdown]
# ### Display price if we have more than five units of inventory
#
# Now, write logic that displays the price of our product if we have more than five units of inventory, and 0.0 if not.
#
# Our current price is 99.99.

# %%
inventory_count = 5
current_price = 99.99
(inventory_count > 5) * current_price
# Out:
# 0.0

# %% [markdown]
# ### Discount Sale Item Flag
#
# Now write logic that returns True if inventory is greater than 0 and the product price is less than 100 dollars.

# %%
inventory_count > 0 and current_price < 100
# Out:
# True

# %% [markdown]
# ### Special Customer Flag
#
# Finally, we need to create logic that returns True if inventory is greater than 0, or the customer's name is Chris AND the product is named 'super_snowboard'.

# %%
customer_name = 'Chris'
inventory_count = 0
product = 'super_snowboard'

# %%
inventory_count > 0 or (customer_name == 'Chris' and product == 'super_snowboard')
# Out:
# True

# %% [markdown]
# ## The if Statement
# ```
# if coundition:
#     do this
# ```

# %%
price = 499.99

if price > 500:
    print('High price')
elif price > 300:
    print('Medium price')
else:
    print('Low price')

print('This code runs regardless of price')
# Out:
# Medium price
# This code runs regardless of price

# %% [markdown]
# ## Demo: If, Else, Elif

# %%
customer_id = 'C00101'

# %%
int(customer_id.strip('C'))
# Out:
# 101

# %%
if 50 < int(customer_id.strip('C')) <= 100:
    print('You get a small prize!')
elif int(customer_id.strip('C')) <= 50:
    print('You get a big prize!')
else:
    print('Sorry, no luck for you!')
print('OK, back to work!')
# Out:
# Sorry, no luck for you!
# OK, back to work!

# %% [markdown]
# ## Assignment: Control Flow

# %% [markdown]
# ### Inventory Message
#
# Let's add and out of stock flag to our products.
#
# If inventory is negative or 0, print 'OUT OF STOCK'.
# If inventory is greater than 0, and less than or equal to 5, print 'Low Stock'.
# If inventory is anything else, print 'In Stock'

# %%
inventory = 0

# %%
if inventory <= 0:
    print('out of stock'.upper())
elif inventory > 0 and inventory <= 5:
    print('Low Stock')
else:
    print('In Stock')
# Out:
# OUT OF STOCK

# %% [markdown]
# ## Nested Logic
# ```
# if condition1:
#     if condition2:
#         do stuff
#     else:
#         do other stuff
# else:
#     do even other stuff
# ```

# %% [markdown]
# ## Assignment: Nested if Statements

# %% [markdown]
# ### Inventory Message - VIP Request
#
# Hi there, modify the previous inventory logic to handle a special customer.
#
# Print 'Out of Stock' if the inventory is less than or equal to zero, unless our customer's name is Chris.
#
# If inventory is less than or equal to zero, we can give our customer named Chris the display model.
# Modify the logic below to print the following message if the new logic is met:
#
# 'You can have the display model, sir'
# I've pasted the current inventory logic and some test values below. Make sure to test a few different values for each variable.

# %%
inventory = 0
customer_name = 'Chris'

if inventory <= 0:
    print('Out of Stock')
elif inventory <= 5:
    print('Low Stock')
else:
    print('In Stock')
# Out:
# Out of Stock

# %% [markdown]
# ### With Nested Logic

# %%
inventory = 0
customer_name = 'Chris'

if inventory <= 0:
    if customer_name == 'Chris':
        print('You can have the display model, sir')
    else:
        print('Out of Stock')
elif inventory <= 5:
    print('Low Stock')
else:
    print('In Stock')
# Out:
# You can have the display model, sir

# %% [markdown]
# ### Without Nested Logic

# %%
inventory = 0
customer_name = 'Chris'

if inventory <= 0 and customer_name == 'Chris':
    print('You can have the display model, sir')
elif inventory <= 0:
    print('Out of Stock')
elif inventory <= 5:
    print('Low Stock')
else:
    print('In Stock')
# Out:
# You can have the display model, sir
