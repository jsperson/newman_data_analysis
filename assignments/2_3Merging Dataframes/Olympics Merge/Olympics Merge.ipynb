# %% [markdown]
# # Olympics Merge
# Scott Person

# %% [markdown]
# ## Setup the data folder location

# %%
data_folder='./data/'

# %% [markdown]
# ## Python Imports

# %%
import pandas as pd

# %% [markdown]
# ## Import the Data

# %%
df = pd.read_csv(data_folder + 'athlete_events.csv')

# %% [markdown]
# ## Get Statistics and Descriptions about the Data

# %%
df.head()

# %%
df.tail()

# %%
df.sample(10) # --> NOTE: This is an additional often useful method. Try it out. Then look up "pandas .sample() method" to learn what it does.

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### Get Description of Object Columns

# %%
df.describe(include='object')

# %% [markdown]
# ## File Merge

# %%
df_noc = pd.read_csv(data_folder + 'noc_regions.csv')

# %%
df_noc.head()

# %%
df_noc.tail()

# %%
df_noc.sample(10)

# %%
df_noc.shape

# %%
df_noc.info()

# %%
df_noc.describe()

# %%
df = df.merge(df_noc, how='left', on='NOC')

# %%
df.head()

# %%
df.tail()

# %%
df.sample(10)

# %%
df.info()
